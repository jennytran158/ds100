# %%
import pandas as pd
import numpy as np

# %%
boxscore = pd.read_csv('Basketball-BoxScores.csv')
playerboxscore = pd.read_csv('Basketball-PlayerBoxScore.csv')
teamboxscore = pd.read_csv('Basketball-TeamBoxScores.csv')
college = pd.read_csv('college.csv')
standing = pd.read_csv('Standings.csv')

# %%
boxscore.head(10)
# Out:
#        gmDate gmTime  seasTyp      offLNm    offFNm teamAbbr teamConf  \
# 0  2012-10-30  19:00  Regular    Brothers      Tony      WAS     East
# 1  2012-10-30  19:00  Regular       Smith   Michael      WAS     East
# 2  2012-10-30  19:00  Regular     Workman  Haywoode      WAS     East
# 3  2012-10-30  19:00  Regular    Brothers      Tony      CLE     East
# 4  2012-10-30  19:00  Regular       Smith   Michael      CLE     East
# 5  2012-10-30  19:00  Regular     Workman  Haywoode      CLE     East
# 6  2012-10-30  20:00  Regular   McCutchen     Monty      BOS     East
# 7  2012-10-30  20:00  Regular      Wright      Sean      BOS     East
# 8  2012-10-30  20:00  Regular  Fitzgerald      Kane      BOS     East
# 9  2012-10-30  20:00  Regular   McCutchen     Monty      MIA     East
#
#      teamDiv teamLoc teamRslt  ...  opptFIC40  opptOrtg  opptDrtg  opptEDiff  \
# 0  Southeast    Away     Loss  ...    61.6667  105.6882   94.4447    11.2435
# ...

# %%
playerboxscore.head(10)
# Out:
#        gmDate gmTime  seasTyp    playLNm  playFNm teamAbbr teamConf  \
# 0  2012-10-30  19:00  Regular      Price     A.J.      WAS     East
# 1  2012-10-30  19:00  Regular      Ariza   Trevor      WAS     East
# 2  2012-10-30  19:00  Regular     Okafor    Emeka      WAS     East
# 3  2012-10-30  19:00  Regular       Beal  Bradley      WAS     East
# 4  2012-10-30  19:00  Regular     Booker   Trevor      WAS     East
# 5  2012-10-30  19:00  Regular   Crawford   Jordan      WAS     East
# 6  2012-10-30  19:00  Regular    Webster  Martell      WAS     East
# 7  2012-10-30  19:00  Regular     Vesely      Jan      WAS     East
# 8  2012-10-30  19:00  Regular  Singleton    Chris      WAS     East
# 9  2012-10-30  19:00  Regular     Barron     Earl      WAS     East
#
#      teamDiv teamLoc teamRslt  ...  playFT% playORB playDRB playTRB opptAbbr  \
# 0  Southeast    Away     Loss  ...     1.00       1       1       2      CLE
# ...

# %%
teamboxscore.head(10)
# Out:
#        gmDate gmTime  seasTyp    offLNm1  offFNm1    offLNm2  offFNm2  \
# 0  2012-10-30  19:00  Regular   Brothers     Tony      Smith  Michael
# 1  2012-10-30  19:00  Regular   Brothers     Tony      Smith  Michael
# 2  2012-10-30  20:00  Regular  McCutchen    Monty     Wright     Sean
# 3  2012-10-30  20:00  Regular  McCutchen    Monty     Wright     Sean
# 4  2012-10-30  22:30  Regular     Foster    Scott  Zielinski     Gary
# 5  2012-10-30  22:30  Regular     Foster    Scott  Zielinski     Gary
# 6  2012-10-31  19:00  Regular  Salvatore  Bennett      Brown     Tony
# 7  2012-10-31  19:00  Regular  Salvatore  Bennett      Brown     Tony
# 8  2012-10-31  19:00  Regular    Spooner     Bill    Guthrie    David
# 9  2012-10-31  19:00  Regular    Spooner     Bill    Guthrie    David
#
#       offLNm3   offFNm3 teamAbbr  ... opptFIC40  opptOrtg  opptDrtg opptEDiff  \
# 0     Workman  Haywoode      WAS  ...   61.6667  105.6882   94.4447   11.2435
# ...

# %%
college.head(10)
# Out:
#    Unnamed: 0  active_from  active_to         birth_date  \
# 0           0         1991       1995      June 24, 1968
# 1           1         1969       1978      April 7, 1946
# 2           2         1970       1989     April 16, 1947
# 3           3         1991       2001      March 9, 1969
# 4           4         1998       2003   November 3, 1974
# 5           5         1997       2008  December 11, 1976
# 6           6         1977       1981        May 6, 1954
# 7           7         1957       1957      July 27, 1932
# 8           8         1947       1948   February 9, 1919
# 9           9         2017       2018     August 1, 1993
#
#                                              college height  \
# 0                                    Duke University   6-10
# 1                              Iowa State University    6-9
# 2              University of California, Los Angeles    7-2
# 3                         Louisiana State University    6-1
# ...

# %%
standing.head(10)
# Out:
#        stDate teamAbbr  rank rankOrd  gameWon  gameLost stk stkType  stkTot  \
# 0  2012-10-30      ATL     3     3rd        0         0   -       -       0
# 1  2012-10-30      BKN     3     3rd        0         0   -       -       0
# 2  2012-10-30      BOS    14    14th        0         1  L1    loss       1
# 3  2012-10-30      CHA     3     3rd        0         0   -       -       0
# 4  2012-10-30      CHI     3     3rd        0         0   -       -       0
# 5  2012-10-30      CLE     1     1st        1         0  W1     win       1
# 6  2012-10-30      DAL     1     1st        1         0  W1     win       1
# 7  2012-10-30      DEN     2     2nd        0         0   -       -       0
# 8  2012-10-30      DET     3     3rd        0         0   -       -       0
# 9  2012-10-30       GS     2     2nd        0         0   -       -       0
#
#    gameBack  ...  rel%Indx   mov   srs     pw%  pyth%13.91  wpyth13.91  \
# ...
